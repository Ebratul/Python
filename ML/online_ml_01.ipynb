# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebratul/Python/blob/main/ML/online_ml_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn import linear_model

n_samples, n_features = 1, 500

y = np.random.randn(n_samples)
X = np.random.randn(n_samples, n_features)

clf = linear_model.SGDRegressor() #same mechanism of linearRegresson

import time

start_time = time.time()

clf.partial_fit(X, y)

elapsed_time = time.time() - start_time

print(elapsed_time)
# Out:
# 0.0056760311126708984

# %%
y = np.random.randn(n_samples)
X = np.random.randn(n_samples, n_features)

# %%
clf.partial_fit(X, y)
