# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebratul/practices/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
json = response.json()['results']

# %%
df = pd.DataFrame(json)[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     31.7568
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     26.6651
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     16.7408
# 3  The true story of how businessman Oskar Schind...   1993-12-15     11.4912
# 4  The defense and the prosecution have rested an...   1957-04-10     14.8185
#
#    vote_average  vote_count
# 0         8.712       28866
# 1         8.685       21823
# 2         8.570       13182
# 3         8.566       16694
# 4         8.549        9387

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dfs = []
for i in range(1, 429):
    response = requests.get(f"https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}")
    df_temp = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    dfs.append(df_temp)

df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#           id                               title  \
# 0        278            The Shawshank Redemption
# 1        238                       The Godfather
# 2        240               The Godfather Part II
# 3        424                    Schindler's List
# 4        389                        12 Angry Men
# ...      ...                                 ...
# 8555  375588                          Robin Hood
# 8556  146223                      Closed Circuit
# 8557    9072                          Little Man
# 8558  418437                       Unforgettable
# 8559   38031  You Will Meet a Tall Dark Stranger
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
