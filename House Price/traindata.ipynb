# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebratul/Python/blob/main/House%20Price/traindata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv(r"/content/drive/MyDrive/dataset/train.csv")
pd.set_option('display.max_columns', None)

# %%
df.sample(5)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 748  749          20       RL         59.0    10593   Pave   NaN      IR1
# 500  501         160       RM         21.0     1890   Pave   NaN      Reg
# 996  997          20       RL          NaN    10659   Pave   NaN      IR1
# 46    47          50       RL         48.0    12822   Pave   NaN      IR1
# 615  616          85       RL         80.0     8800   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 748         Lvl    AllPub    Inside       Gtl      NoRidge       Norm
# 500         Lvl    AllPub    Inside       Gtl       BrDale       Norm
# 996         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 46          Lvl    AllPub   CulDSac       Gtl      Mitchel       Norm
# 615         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
sb.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <Axes: >

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
df = df.drop(columns=['MiscFeature','Fence', 'PoolQC', 'FireplaceQu','MasVnrType' ,'Alley'])

# %%
df.shape
# Out:
# (1460, 75)

# %%
plt.figure(figsize=(12,6))
sb.heatmap(df.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
df.sample(7)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1270  1271          40       RL          NaN    23595   Pave      Reg
# 756    757          60       RL         68.0    10769   Pave      IR1
# 176    177          60       RL         97.0    10029   Pave      IR1
# 1217  1218          20       FV         72.0     8640   Pave      Reg
# 122    123          20       RL         75.0     9464   Pave      Reg
# 1398  1399          50       RL         60.0     7200   Pave      Reg
# 421    422          20       RL          NaN    16635   Pave      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1270         Low    AllPub    Inside       Sev      ClearCr       Norm
# 756          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 176          Lvl    AllPub    Corner       Gtl      ClearCr       Norm
# 1217         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# ...

# %%
#Fill missing values
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df['BsmtQual'].value_counts()
# Out:
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64

# %%
df['BsmtCond'].value_counts()
# Out:
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64

# %%
df['BsmtQual'] = df['BsmtQual'].fillna(df['BsmtQual'].mode()[0])
df['BsmtCond'] = df['BsmtCond'].fillna(df['BsmtCond'].mode()[0])

# %%
df['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64

# %%
df['BsmtFinType1'].value_counts()
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64

# %%
df['BsmtFinType2'].value_counts()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
df['BsmtExposure'] = df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0])
df['BsmtFinType1'] = df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode()[0])
df['BsmtFinType2'] = df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0])

# %%
df['GarageType'].value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
df['GarageYrBlt'].value_counts()
# Out:
# GarageYrBlt
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
# 1977.0    35
# 1998.0    31
# 1999.0    30
# 1976.0    29
# 2008.0    29
# 2000.0    27
# 1968.0    26
# 2002.0    26
# 1950.0    24
# 1993.0    22
# 1965.0    21
# 1966.0    21
# 1958.0    21
# 2009.0    21
# 1962.0    21
# 1970.0    20
# 1996.0    20
# 2001.0    20
# 1957.0    20
# 1954.0    19
# 1960.0    19
# 1978.0    19
# 1997.0    19
# 1974.0    18
# 1964.0    18
# 1995.0    18
# 1994.0    18
# 1959.0    17
# 1990.0    16
# 1963.0    16
# 1956.0    16
# 1967.0    15
# 1980.0    15
# 1979.0    15
# 1969.0    15
# 1920.0    14
# 1940.0    14
# 1972.0    14
# 1973.0    14
# 1988.0    14
# 1971.0    13
# 1961.0    13
# 1955.0    13
# 1992.0    13
# 1953.0    12
# 1987.0    11
# 1948.0    11
# 1925.0    10
# 1941.0    10
# 1985.0    10
# 1981.0    10
# 1989.0    10
# 1939.0     9
# 1975.0     9
# 1991.0     9
# 1930.0     8
# 1949.0     8
# 1984.0     8
# 1983.0     7
# 1926.0     6
# ...

# %%
df['GarageFinish'].value_counts()
# Out:
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# Name: count, dtype: int64

# %%
df['GarageQual'].value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
df['GarageCond'].value_counts()
# Out:
# GarageCond
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64

# %%
df['GarageType'] = df['GarageType'].fillna(df['GarageType'].mode()[0])
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mode()[0])
df['GarageFinish'] = df['GarageFinish'].fillna(df['GarageFinish'].mode()[0])
df['GarageQual'] = df['GarageQual'].fillna(df['GarageQual'].mode()[0])
df['GarageCond'] = df['GarageCond'].fillna(df['GarageCond'].mode()[0])

# %%
# df.drop(['Id'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (1460, 75)

# %%
plt.figure(figsize=(12,6))
sb.heatmap(df.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1451, 75)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
# 2     2Story            7            5       2001          2002     Gable
#
# ...

# %%
columns = [
    'MSZoning',
    'Street',
    'LotShape',
    'LandContour',
    'Utilities',
    'LotConfig',
    'LandSlope',
    'Neighborhood',
    'Condition1',
    'Condition2',
    'BldgType',
    'HouseStyle',
    'RoofStyle',
    'RoofMatl',
    'Exterior1st',
    'Exterior2nd',
    'ExterQual',
    'ExterCond',
    'Foundation',
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'Heating',
    'HeatingQC',
    'CentralAir',
    'Electrical',
    'KitchenQual',
    'Functional',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
    'PavedDrive',
    'SaleType',
    'SaleCondition'
]

# %%
# y_df_test = df[['SalePrice']]
# y_df_test=y_df_test.iloc[:1422,:]

# %%
# y_df_test=y_df_test.iloc[:1422,:]

# %%
# y_df_test.shape

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:

        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)

        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:

            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1


    df_final=pd.concat([final_df,df_final],axis=1)

    return df_final

# %%
main_df = df.copy()

# %%
# df.drop(['Id'], axis = 1, inplace = True)

# %%
test_df = pd.read_csv(r"/content/drive/MyDrive/dataset/formulatedTest.csv")
test_df.head(3)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
# 2  1463          60       RL         74.0    13830   Pave      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  MasVnrArea  \
# ...

# %%
test_df.shape
# Out:
# (1449, 74)

# %%
test_df.drop(['Id'], axis = 1, inplace = True)

# %%
final_df = pd.concat([df, test_df], axis= 0)

# %%
final_df.shape
# Out:
# (2900, 75)

# %%
final_df.head(4)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0  1.0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1  2.0          20       RL         80.0     9600   Pave      Reg         Lvl
# 2  3.0          60       RL         68.0    11250   Pave      IR1         Lvl
# 3  4.0          70       RL         60.0     9550   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# ...

# %%
final_df = category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# SaleType
# SaleCondition

# %%
final_df.head(5)
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0  1.0          60         65.0     8450            7            5       2003
# 1  2.0          20         80.0     9600            6            8       1976
# 2  3.0          60         68.0    11250            7            5       2001
# 3  4.0          70         60.0     9550            7            5       1915
# 4  5.0          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0       706.0         0.0      150.0        856.0
# 1          1976         0.0       978.0         0.0      284.0       1262.0
# 2          2002       162.0       486.0         0.0      434.0        920.0
# 3          1970         0.0       216.0         0.0      540.0        756.0
# 4          2000       350.0       655.0         0.0      490.0       1145.0
#
# ...

# %%
final_df.columns[final_df.columns.duplicated()]
# Out:
# Index(['Feedr', 'Norm', 'PosA', 'PosN', 'RRAe', 'RRAn', 'RRNn', 'AsphShn',
#        'BrkFace', 'CBlock', 'HdBoard', 'ImStucc', 'MetalSd', 'Plywood',
#        'Stone', 'Stucco', 'VinylSd', 'Wd Sdng', 'Fa', 'Gd', 'TA', 'CBlock',
#        'Stone', 'Fa', 'Gd', 'TA', 'Gd', 'Po', 'TA', 'Gd', 'BLQ', 'GLQ', 'LwQ',
#        'Rec', 'Unf', 'Fa', 'Gd', 'Po', 'TA', 'Fa', 'Gd', 'TA', 'Mod', 'Sev',
#        'Unf', 'Fa', 'Gd', 'Po', 'TA', 'Fa', 'Gd', 'Po', 'TA', 'Y'],
#       dtype='object')

# %%
#যদি শুধু unique columns রাখতে চাও:
final_df = final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.head(3)
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0  1.0          60         65.0     8450            7            5       2003
# 1  2.0          20         80.0     9600            6            8       1976
# 2  3.0          60         68.0    11250            7            5       2001
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0       706.0         0.0      150.0        856.0
# 1          1976         0.0       978.0         0.0      284.0       1262.0
# 2          2002       162.0       486.0         0.0      434.0        920.0
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710           1.0           0.0
# 1      1262         0             0       1262           0.0           1.0
# 2       920       866             0       1786           1.0           0.0
#
# ...

# %%
# final_df.drop(columns=['Id'],inplace=True)

# %%
final_df.shape
# Out:
# (2900, 177)

# %%
df_train = final_df.iloc[:1422,:]
df_test = final_df.iloc[1422:,:]

# %%
df_train.head(3)
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0  1.0          60         65.0     8450            7            5       2003
# 1  2.0          20         80.0     9600            6            8       1976
# 2  3.0          60         68.0    11250            7            5       2001
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0       706.0         0.0      150.0        856.0
# 1          1976         0.0       978.0         0.0      284.0       1262.0
# 2          2002       162.0       486.0         0.0      434.0        920.0
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710           1.0           0.0
# 1      1262         0             0       1262           0.0           1.0
# 2       920       866             0       1786           1.0           0.0
#
# ...

# %%
df_test.head(3)
# Out:
#           Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1431  1432.0         120    70.049958     4928            6            6
# 1432  1433.0          30    60.000000    10800            4            6
# 1433  1434.0          60    93.000000    10261            6            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1431       1976          1976         0.0       958.0         0.0        0.0
# 1432       1927          2007         0.0         0.0         0.0      656.0
# 1433       2000          2000       318.0         0.0         0.0      936.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 1431        958.0       958         0             0        958           0.0
# 1432        656.0       968         0             0        968           0.0
# 1433        936.0       962       830             0       1792           1.0
#
# ...

# %%
df_test.shape
# Out:
# (1478, 177)

# %%
df_test.drop(['SalePrice'], axis=1,inplace=True)

# %%
df_train['SalePrice'].head(3)
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# Name: SalePrice, dtype: float64

# %%
df_test = df_test.iloc[:1422,:]
df_test.columns.difference(df_train.columns)
# Out:
# Index([], dtype='object')

# %%
df_test.head()
# Out:
#           Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1431  1432.0         120    70.049958     4928            6            6
# 1432  1433.0          30    60.000000    10800            4            6
# 1433  1434.0          60    93.000000    10261            6            5
# 1434  1435.0          20    80.000000    17400            5            5
# 1435  1436.0          20    80.000000     8400            6            9
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1431       1976          1976         0.0       958.0         0.0        0.0
# 1432       1927          2007         0.0         0.0         0.0      656.0
# 1433       2000          2000       318.0         0.0         0.0      936.0
# 1434       1977          1977         0.0       936.0         0.0      190.0
# 1435       1962          2005       237.0         0.0         0.0     1319.0
#
# ...

# %%
x_train = df_train.drop(['SalePrice'], axis = 1)
y_train = df_train['SalePrice']

# %%
x_train.shape
# Out:
# (1422, 176)

# %%
import xgboost
xgb=xgboost.XGBRegressor()
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(df_test)
len(y_pred)
# Out:
# 1422

# %%
y_train = y_train.to_numpy()

# %%
from sklearn.metrics import mean_absolute_error
score = mean_absolute_error(y_train, y_pred)
score
# Out:
# 79600.61828355749

# %%
xgb.score(x_train, y_train)
# Out:
# 0.9995762710107099

# %%
# #Hyper parameter Optimization

# n_estimators = [100, 500, 900, 1100, 1500]

# max_depth = [2, 3, 5, 10, 15]
# booster = ['gbtree','gblinear']
# learning_rate = [0.05, 0.1, 0.15, 0.20]
# min_child_weight = [1, 2, 3, 4]
# base_score = [0.25, 0.5, 0.75, 1]
# # define the grid of hyperparameters to search

# hyperparameter_grid = {
#     'n_estimators': n_estimators,
#     'max_depth':max_depth,
#     'learning_rate':learning_rate,
#     'min_child_weight':min_child_weight,
#     'booster':booster,
#     'base_score': base_score
# }

# %%
# from sklearn.model_selection import RandomizedSearchCV

# %%
# random_cv = RandomizedSearchCV(
#     estimator = xgb,
#     param_distributions= hyperparameter_grid,
#     cv = 5,
#     n_iter = 50,
#     scoring = 'neg_mean_absolute_error',
#     n_jobs=4,
#     verbose = 5,
#     return_train_score = True,
#     random_state = 42
# )

# %%
# random_cv.fit(x_train, y_train)

# %%
# random_cv.best_estimator_

# %%
import numpy as np
import xgboost as xgb

regressor = xgb.XGBRegressor(
    base_score=0.25,
    booster='gbtree',
    colsample_bylevel=1,
    colsample_bytree=1,
    gamma=0,
    learning_rate=0.1,
    max_delta_step=0,
    max_depth=2,
    min_child_weight=1,
    missing=np.nan,  # <-- এখানে np.nan ব্যবহার করতে হবে
    n_estimators=900,
    n_jobs=1,
    objective='reg:squarederror',
    random_state=0,
    reg_alpha=0,
    reg_lambda=1,
    scale_pos_weight=1,
    subsample=1,
    verbosity=0
)

regressor.fit(x_train, y_train)

y_pred = regressor.predict(df_test)
len(y_pred)
# Out:
# 1422

# %%
from sklearn.metrics import mean_absolute_error
score = mean_absolute_error(y_train, y_pred)
score
# Out:
# 81050.93705498418

# %%
import pickle
filename = 'finalized_model.pkl'
pickle.dump(regressor, open(filename, 'wb'))

# %%
y_pred = regressor.predict(df_test)

# %%
y_pred
# Out:
# array([133731.98 , 107915.766, 181144.72 , ..., 119842.11 , 188954.67 ,
#        138675.58 ], dtype=float32)

# %%
pred = pd.DataFrame(y_pred)
sub_df = pd.read_csv("/content/drive/MyDrive/dataset/sample_submission.csv")
datasets = pd.DataFrame()
datasets["Id"] = sub_df["Id"].astype(int)
datasets["SalePrice"] = pred.iloc[:,0]
datasets.to_csv('/content/sample_data/sample_submission.csv', index=False)

# %%
df = pd.read_csv(r"/content/sample_data/sample_submission.csv")
df.head()
# Out:
#      Id   SalePrice
# 0  1461  133731.980
# 1  1462  107915.766
# 2  1463  181144.720
# 3  1464  173746.030
# 4  1465  175668.060

# %%
df.shape
# Out:
# (1459, 2)

# %%
corr = df_train.corr()
corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.013532    -0.013616 -0.032146    -0.030931
# MSSubClass     0.013532    1.000000    -0.351318 -0.134172     0.037152
# LotFrontage   -0.013616   -0.351318     1.000000  0.306013     0.230690
# LotArea       -0.032146   -0.134172     0.306013  1.000000     0.108171
# OverallQual   -0.030931    0.037152     0.230690  0.108171     1.000000
# OverallCond    0.003890   -0.061323    -0.052506 -0.002282    -0.088319
# YearBuilt     -0.020469    0.026320     0.117433  0.016859     0.573889
# YearRemodAdd  -0.036558    0.043120     0.080500  0.016685     0.554509
# MasVnrArea    -0.048051    0.025179     0.177369  0.103728     0.410117
# BsmtFinSF1    -0.002887   -0.072678     0.218371  0.214721     0.235796
# BsmtFinSF2    -0.012360   -0.064602     0.044542  0.114558    -0.055808
# BsmtUnfSF     -0.007177   -0.131969     0.118731 -0.005976     0.312429
# ...

# %%
# Boolean mask: শুরুতে সব কলামকে True ধরা
columns = np.ones(corr.shape[0], dtype=bool)

# Highly correlated কলাম বাদ দেওয়া
for i in range(corr.shape[0]):
    for j in range(i + 1, corr.shape[0]):
        if corr.iloc[i, j] >= 0.9:   # যদি correlation ≥ 0.9 হয়
            columns[j] = False       # দ্বিতীয় কলামটি বাদ দাও

# Only selected columns
selected_columns = df_train.columns[columns]
data = df_train[selected_columns]

# %%
import numpy as np

# %%
# num_true = np.sum(columns)
# num_false = np.sum(~columns)
# num_false
# Out:
# np.int64(2)
