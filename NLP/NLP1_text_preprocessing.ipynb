# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebratul/Python/blob/main/NLP/NLP1_text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/IMDB Dataset.csv')

# %%
df.head(5)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# # lowercasing

# %%
df['review']=df['review'].str.lower()

# %%
df['review'][0]
# Out:
# "one of the other reviewers has mentioned that after watching just 1 oz episode you'll be hooked. they are right, as this is exactly what happened with me.<br /><br />the first thing that struck me about oz was its brutality and unflinching scenes of violence, which set in right from the word go. trust me, this is not a show for the faint hearted or timid. this show pulls no punches with regards to drugs, sex or violence. its is hardcore, in the classic use of the word.<br /><br />it is called oz as that is the nickname given to the oswald maximum security state penitentary. it focuses mainly on emerald city, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. em city is home to many..aryans, muslims, gangstas, latinos, christians, italians, irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />i would say the main appeal of the show is due to the 
# ...

# %% [markdown]
# #Remove HTML tag

# %%
import re #regular expression

# %%
def remove_html(text):
  pattern = re.compile('<.*?>')
  return pattern.sub(r'', text)

# %%
df['review'] = df['review'].apply(remove_html)

# %%
df['review'][3]
# Out:
# "basically there's a family where a little boy (jake) thinks there's a zombie in his closet & his parents are fighting all the time.this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie.ok, first of all when you're going to make a film you must decide if its a thriller or a drama! as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film! i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake: just ignore them."

# %% [markdown]
# # remove URL

# %%
def remove_url(text):
    pattern = re.compile(r'http\S+|www\.\S+')
    return pattern.sub('', text)

# %%
text = "Check this out http://example.com and also visit www.test.com for more info."
clean_text = remove_url(text)

print(clean_text)
# Out:
# Check this out  and also visit  for more info.

# %%
df['review'] = df['review'].apply(remove_url)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production. the filming tec...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's "love in the time of money" is...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # Remove punctuation

# %%
import string,time

# %%
pun = string.punctuation
pun
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# def remove_punctuation(text):
#   for char in pun:
#     text = text.replace(char,'')
#   return text

# %%
# text = "Hello, world! This is NLP... #awesome"
# clean_text = remove_punctuation(text)
# clean_text
# #

# %%
# df['review'] = df['review'].apply(remove_punctuation)

# %%
# start = time.time()
# print(remove_punctuation(text))
# time1 = time.time() - start
# print(time1 * 500000)

# %%
def remove_punctuatioN(text):
    return text.translate(str.maketrans('', '', pun))

# %%
text1 = "Hello, world! This is NLP... #awesome"
clean_text = remove_punctuatioN(text)
clean_text
# Out:
# 'Check this out httpexamplecom and also visit wwwtestcom for more info'

# %%
start1 = time.time()
print("=",start1)
print(remove_punctuatioN(text1))
time2 = time.time() - start1
print(time2 * 500000)
# Out:
# = 1762491717.3301523
# Hello world This is NLP awesome
# 114.08329010009766

# %%
# time1/time2

# %%
df['review'] = df['review'].apply(remove_punctuatioN)
df['review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production the filming tech...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically theres a family where a little boy j...
# 4        petter matteis love in the time of money is a ...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot bad dialogue bad acting idiotic direc...
# 49997    i am a catholic taught in parochial elementary...
# 49998    im going to have to disagree with the previous...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %% [markdown]
# #sortword full meaning

# %%
slang_word = abbr_dict = {
    "A3": "Anytime, Anywhere, Anyplace",
    "ADIH": "Another Day In Hell",
    "AFK": "Away From Keyboard",
    "AFAIK": "As Far As I Know",
    "ASAP": "As Soon As Possible",
    "ASL": "Age, Sex, Location",
    "ATK": "At The Keyboard",
    "ATM": "At The Moment",
    "BAE": "Before Anyone Else",
    "BAK": "Back At Keyboard",
    "BBL": "Be Back Later",
    "BBS": "Be Back Soon",
    "BFN": "Bye For Now",
    "B4N": "Bye For Now",
    "BRB": "Be Right Back",
    "BRUH": "Bro",
    "BRT": "Be Right There",
    "BSAAW": "Big Smile And A Wink",
    "BTW": "By The Way",
    "BWL": "Bursting With Laughter",
    "CSL": "Can’t Stop Laughing",
    "CU": "See You",
    "CUL8R": "See You Later",
    "CYA": "See You",
    "DM": "Direct Message",
    "FAQ": "Frequently Asked Questions",
    "FC": "Fingers Crossed",
    "FIMH": "Forever In My Heart",
    "FOMO": "Fear Of Missing Out",
    "FR": "For Real",
    "FWIW": "For What It's Worth",
    "FYP": "For You Page",
    "FYI": "For Your Information",
    "G9": "Genius",
    "GAL": "Get A Life",
    "GG": "Good Game",
    "GMTA": "Great Minds Think Alike",
    "GN": "Good Night",
    "GOAT": "Greatest Of All Time",
    "GR8": "Great!",
    "HBD": "Happy Birthday",
    "IC": "I See",
    "ICQ": "I Seek You",
    "IDC": "I Don’t Care",
    "IDK": "I Don't Know",
    "IFYP": "I Feel Your Pain",
    "ILU": "I Love You",
    "ILY": "I Love You",
    "IMHO": "In My Honest/Humble Opinion",
    "IMU": "I Miss You",
    "IMO": "In My Opinion",
    "IOW": "In Other Words",
    "IRL": "In Real Life",
    "IYKYK": "If You Know, You Know",
    "JK": "Just Kidding",
    "KISS": "Keep It Simple, Stupid",
    "L": "Loss",
    "L8R": "Later",
    "LDR": "Long Distance Relations"
}

# %%
def sms_slang_translator(text):
  new_text = []
  for i in text.split():
    if i.upper() in slang_word:
      new_text.append(slang_word[i.upper()])
    else:
       new_text.append(i)
  return " ".join(new_text)

# %%
sms_slang_translator('LDR he is best')
# Out:
# 'Long Distance Relations he is best'

# %%
df['review'] = df['review'].apply(sms_slang_translator)
df['review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production the filming tech...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically theres a family where a little boy j...
# 4        petter matteis love in the time of money is a ...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot bad dialogue bad acting idiotic direc...
# 49997    i am a catholic taught in parochial elementary...
# 49998    im going to have to disagree with the previous...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %% [markdown]
# #spelling mistake

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
incorrect_text = "I loove Python. It is awesoome!"

# %%
textBlb = TextBlob(incorrect_text)
textBlb.correct().string
# Out:
# 'I love Python. It is awesoome!'

# %%
# corrected_reviews = []
# for text in df['review']:
#     blob = TextBlob(str(text))
    # corrected_text = blob.correct()
#     corrected_reviews.append(corrected_text.string)

# df['review'] = corrected_reviews

# %%
# df['review'] = df['review'].apply(lambda text: TextBlob(str(text)).correct().string)

# %% [markdown]
# # remove stopword

# %%
# !pip install nltk

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove_stopwords(text):
  new_text = []
  for word in text.split():
    if word in stopwords.words('english'):
      new_text.append('')
    else:
      new_text.append(word)
  x = new_text[:]
  new_text.clear()
  return " ".join(x) # make sentance

# %%
text = "This is a simple example showing stopwords removal ,Python is great for NLP tasks"

# %%
# text.split()

# %%
remove_stopwords(text)
# Out:
# 'This   simple example showing stopwords removal ,Python  great  NLP tasks'

# %%
# df['review'] = df['review'].apply(remove_stopwords)
# df['review']

# %%
import re

def remove_emoji(text):
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons 😀 😃 😄
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs 🌟 🌍
        u"\U0001F680-\U0001F6FF"  # transport & map symbols 🚗 🚀
        u"\U0001F1E0-\U0001F1FF"  # flags 🏳️‍🌈 🏴‍☠️
        u"\U00002700-\U000027BF"  # other symbols ✨ ❌
        u"\U000024C2-\U0001F251"  # enclosed characters
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# %%
# উদাহরণ
text = "I love Python 😍🔥🚀! It's awesome 😂👍"
clean_text = remove_emoji(text)

print(clean_text)
# Out:
# I love Python ! It's awesome

# %%
df['review'] = df['review'].apply(remove_emoji)
df['review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production the filming tech...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically theres a family where a little boy j...
# 4        petter matteis love in the time of money is a ...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot bad dialogue bad acting idiotic direc...
# 49997    i am a catholic taught in parochial elementary...
# 49998    im going to have to disagree with the previous...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %% [markdown]
# # remove emoji using build in function

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 21.6 MB/s eta 0:00:00
# ...

# %%
import emoji

def replace_emoji(text):
    return emoji.demojize(text, language="en")

# %%
text = "I love Python 😍🔥🚀! It's awesome 😂👍"
clean_text = replace_emoji(text)

print(clean_text)
# Out:
# I love Python :smiling_face_with_heart-eyes::fire::rocket:! It's awesome :face_with_tears_of_joy::thumbs_up:

# %%
df['review'] = df['review'].apply(remove_emoji)
df['review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production the filming tech...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically theres a family where a little boy j...
# 4        petter matteis love in the time of money is a ...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot bad dialogue bad acting idiotic direc...
# 49997    i am a catholic taught in parochial elementary...
# 49998    im going to have to disagree with the previous...
# 49999    no one expects the star trek movies to be high...
# Name: review, Length: 50000, dtype: object

# %% [markdown]
# #Tokenization

# %% [markdown]
# word tokenization

# %%
text1 = "I am learning data science every day.The weather is very beautiful today."
text1.split()
# Out:
# ['I',
#  'am',
#  'learning',
#  'data',
#  'science',
#  'every',
#  'day.The',
#  'weather',
#  'is',
#  'very',
#  'beautiful',
#  'today.']

# %%
#sentence tokenization
text1.split('.')
# Out:
# ['I am learning data science every day',
#  'The weather is very beautiful today',
#  '']

# %%
text1 = "am  I learning data science every day?The weather is very beautiful today."
text1.split('.')
# Out:
# ['am  I learning data science every day?The weather is very beautiful today',
#  '']

# %% [markdown]
# #regular expression

# %%
import re
tokens = re.findall('[\w]+', text1)
tokens
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2824886250.py:2: SyntaxWarning: invalid escape sequence '\w'
#   tokens = re.findall('[\w]+', text1)
# ['am',
#  'I',
#  'learning',
#  'data',
#  'science',
#  'every',
#  'day',
#  'The',
#  'weather',
#  'is',
#  'very',
#  'beautiful',
#  'today']

# %%
text2 = "Wow! That movie was really amazing! Please, don’t forget to bring your notebook tomorrow. I have three favorite fruits: mango, apple, and banana. He asked, Where are you going? It’s raining outside — shall we stay home or go out?"
tokens = re.findall('[\w]+', text2)

text2
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2192465634.py:2: SyntaxWarning: invalid escape sequence '\w'
#   tokens = re.findall('[\w]+', text2)
# 'Wow! That movie was really amazing! Please, don’t forget to bring your notebook tomorrow. I have three favorite fruits: mango, apple, and banana. He asked, Where are you going? It’s raining outside — shall we stay home or go out?'

# %% [markdown]
# #NLTK

# %% [markdown]
# word tokenized

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize

text2 = "Wow! That movie was really amazing! Please, don’t forget to bring your notebook tomorrow. My email id is ebratulshaharier@gmail.com"
tokens = word_tokenize(text2)
print(tokens)
# Out:
# ['Wow', '!', 'That', 'movie', 'was', 'really', 'amazing', '!', 'Please', ',', 'don', '’', 't', 'forget', 'to', 'bring', 'your', 'notebook', 'tomorrow', '.', 'My', 'email', 'id', 'is', 'ebratulshaharier', '@', 'gmail.com']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#sentance tokenize
sent_tokenize(text2)
# Out:
# ['Wow!',
#  'That movie was really amazing!',
#  'Please, don’t forget to bring your notebook tomorrow.',
#  'My email id is ebratulshaharier@gmail.com']

# %% [markdown]
# #spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1 = nlp(text2)
# doc1

# %%
for token in doc1:
  print(token)
# Out:
# Wow
# !
# That
# movie
# was
# really
# amazing
# !
# Please
# ,
# do
# n’t
# forget
# to
# bring
# your
# notebook
# tomorrow
# .
# My
# email
# i
# d
# is
# ebratulshaharier@gmail.com

# %% [markdown]
# #stemming & lemmatization

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

# %%
def stem_words(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
sample = "walk walks walking walked"
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text =  "The children were playing happily in the playground.Their teacher was watching them carefully.One child fell down and started crying loudly.The teacher came quikly and helped the child stand up.After a few minutes, the child was smiling again."

# %%
stem_words(text)
# Out:
# 'the children were play happili in the playground.their teacher wa watch them carefully.on child fell down and start cri loudly.th teacher came quikli and help the child stand up.aft a few minutes, the child wa smile again.'

# %%
# Lemmatization
# from nltk.stem import WordNetLemmatizer
# import nltk
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
# punctuation = "?;.!,:"
# sentence_word = nltk.word_tokenize(text)
# sentence_word

# %%
# for word in sentence_word:
#   if word in punctuation:
#     sentence_word.remove(word)
# sentence_word

# %%
# print("{0:20}{1:20}".format("word", "Lemma"))

# for word in sentence_word:
#   print("{0:20}{1:20}".format(word, lemmatizer.lemmatize(word, pos='v')))


sentence =  "The children were playing happily in the playground.Their teacher was watching them carefully.One child fell down and started crying loudly.The teacher came quikly and helped the child stand up.After a few minutes, the child was smiling again."
sentence_word = word_tokenize(sentence)

lemmatizer = WordNetLemmatizer()

print("{0:20}{1:20}".format("Word", "Lemma (verb)"))
print("-"*40)

for word in sentence_word:
    print("{0:20}{1:20}".format(word, lemmatizer.lemmatize(word, pos='v')))
# Out:
# Word                Lemma (verb)
# ----------------------------------------
# The                 The
# children            children
# were                be
# playing             play
# happily             happily
# in                  in
# the                 the
# playground.Their    playground.Their
# teacher             teacher
# was                 be
# watching            watch
# them                them
# carefully.One       carefully.One
# child               child
# fell                fell
# down                down
# and                 and
# started             start
# crying              cry
# loudly.The          loudly.The
# teacher             teacher
# came                come
# quikly              quikly
# and                 and
# helped              help
# the                 the
# child               child
# stand               stand
# up.After            up.After
# a                   a
# few                 few
# minutes             minutes
# ...
